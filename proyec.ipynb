# %%
import json
import pandas as pd
import gzip
import ast

# Reemplaza 'ruta_del_archivo.json.gz' con la ruta real de tu archivo JSON comprimido en formato gzip
archivo_json = 'C:\\Users\\mikej\\Downloads\\steam_games.json.gz'

files_games = []

with gzip.open(archivo_json, 'rt', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line)
        files_games.append(data)

df_steam_games = pd.DataFrame(files_games)
df_steam_games
# Out:
#               publisher                                 genres  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# ...

# %%
#Elimino valores nulos:
umbral = 3
df_steamgames_sin = df_steam_games.dropna(thresh=len(df_steam_games.columns) - umbral + 1)

# %%
reviews_path = 'C:\\Users\\mikej\\Downloads\\user_reviews.json.gz'
reviews = []
with gzip.open(reviews_path, 'r') as f:
    for line in f.readlines():
        reviews.append(ast.literal_eval(line.decode("utf8")))

        

df_reviews = pd.DataFrame(reviews)
df_reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %%
#Y para desanidarlo para este caso, por ejemplo algo así: 

reviews = pd.json_normalize(df_reviews['reviews'].apply(lambda x: x[0] if x else None))

df_reviews = pd.concat([df_reviews, reviews], axis=1)

df_reviews = df_reviews.drop('reviews', axis=1)
df_reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
# ...

# %%
#Elimino las columnas que no voy a necesitar:
columnas_a_eliminar = ["funny", "posted", "last_edited","item_id","helpful"]
df_reviews_ok = df_reviews.drop(columnas_a_eliminar, axis=1)

# %%
#Elimino valores nulos:
umbral = 3
df_reviewsok_sin = df_reviews_ok.dropna(thresh=len(df_reviews_ok.columns) - umbral + 1)

# %%
#abro archivo que descargue desde google colab sin columnas inecesarias y ya desanidado:

# Carga el archivo CSV en un DataFrame
df_items = pd.read_csv('C:\\Users\\mikej\\Downloads\\items.csv')

df_items
# Out:
#        Unnamed: 0                  user_id  \
# 0               0        76561197970982479
# 1               1                  js41637
# 2               2                evcentric
# 3               3               Riot-Punch
# 4               4                    doctr
# ...           ...                      ...
# 88305       88305        76561198323066619
# 88306       88306        76561198326700687
# 88307       88307  XxLaughingJackClown77xX
# 88308       88308        76561198329548331
# 88309       88309        edward_tremethick
#
#                                                 user_url   item_id  \
# 0      http://steamcommunity.com/profiles/76561197970...      10.0
# 1                   http://steamcommunity.com/id/js41637      10.0
# 2                 http://steamcommunity.com/id/evcentric    1200.0
# 3                http://steamcommunity.com/id/Riot-Punch      10.0
# 4                     http://steamcommunity.com/id/doctr     300.0
# ...

# %%
#Elimino valores nulos:
umbral = 3
df_items_sin = df_items.dropna(thresh=len(df_items.columns) - umbral + 1)

# %%
#Descargo las herramientas necesarias para el analisis de sentimientos solicitado:
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\mikej\AppData\Roaming\nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Inicializo el analizador de sentimientos de VADER
sia = SentimentIntensityAnalyzer()

 #Creo la funcion para obtener el analisis de sentimiento:
def obtener_sentimiento(texto):
    if isinstance(texto, str):
        sentiment_scores = sia.polarity_scores(texto)
        compound_score = sentiment_scores['compound']
        
        if compound_score >= 0.05:
            return 2  # Positivo
        elif compound_score <= -0.05:
            return 0  # Malo
        else:
            return 1  # Neutral
    else:
        return 1  # Si no hay reseña, valor neutral

# Aplico la función de análisis de sentimiento a la columna 'review' y creo la columna 'sentiment_analysis'
df_reviewsok_sin['sentiment_analysis'] = df_reviewsok_sin['review'].apply(obtener_sentimiento)

# Elimino la columna 'review'
df_reviewsok_sin.drop(columns=['review'], inplace=True)

# %%
#Importo las herramientas necesarias para la crecion de la API:
from fastapi import FastAPI
from typing import List, Dict

app = FastAPI()

# %%
# Reemplazo los  datos con la lógica real de acuerdo al  conjunto de datos.


@app.get('/PlayTimeGenre')
async def PlayTimeGenre(genero: str):
    genero_con_mas_horas = df_items_sin[df_items_sin['playtime_forever'] == df_items_sin['playtime_forever'].max()]

    # Obtengo el año de lanzamiento del género desde el df_steamgames_sin:
    genero_id = genero_con_mas_horas['genres'].iloc[0]
    año_con_mas_horas = df_steamgames_sin[df_steamgames_sin['genres'] == genero_id]['release_date'].iloc[0]

    return {"Año de lanzamiento con más horas jugadas para el gérnero": año_con_mas_horas}

@app.get('/UserForGenre')
async def UserForGenre(genero: str):
    # Filtro el DataFrame df_steamgames_sin por el género especificado
    df_genero = df_steamgames_sin[df_steamgames_sin['genero_columna'] == genero]

    # Verifico si se encontro datos para el género especificado
    if df_genero.empty:
        return {"mensaje": f"No se encontraron datos para el género {genero}"}

    # Calculo el usuario con más horas jugadas para el género
    usuario_mas_horas = df_items_sin.groupby('user_id')['playtime_forever'].sum().idxmax()

    # Creo una nueva columna 'year' para extraer el año de la fecha
    df_genero['year'] = df_genero['fecha_columna'].dt.year

    # Calculo la acumulación de horas jugadas por año para el género
    acumulacion_por_año = df_genero.groupby('year')['playtime_forever'].sum().to_dict()

    return {
        "Usuario con más horas jugadas para Género X": usuario_mas_horas,
        "Acumulación de horas jugadas por año para Género X": acumulacion_por_año
    }
@app.get('/UsersRecommend')
async def UsersRecommend(año: int):
    # Filtra df_steamgames_sin para obtener los juegos lanzados en o antes del año especificado
    juegos_del_año_o_antes = df_steamgames_sin[df_steamgames_sin['release_date'].dt.year <= año]

    # Obtén los nombres de los juegos lanzados en o antes del año especificado
    juegos_lanzados_hasta_ano = juegos_del_año_o_antes['nombre_del_juego']

    # Filtra df_reviews para obtener las reseñas de los juegos lanzados en o antes del año especificado
    reseñas_del_año_o_antes = df_reviews[df_reviews['nombre_del_juego'].isin(juegos_lanzados_hasta_ano)]

    # Agrupa las reseñas por el nombre del juego y calcula el promedio de las recomendaciones
    promedio_recomendaciones_por_juego = reseñas_del_año_o_antes.groupby('nombre_del_juego')['recommend'].mean()

    # Ordena los juegos por promedio de recomendaciones en orden descendente y toma los 3 mejores
    top_3_juegos_recomendados = promedio_recomendaciones_por_juego.nlargest(3)

    return {"Top 3 de juegos más recomendados lanzados hasta el año {}: {}".format(año, top_3_juegos_recomendados.to_dict())}

# %%
@app.get('/UsersRecommend')
async def UsersRecommend(año: int):
    # Filtro df_steamgames_sin para obtener los juegos lanzados en o antes del año especificado:
    juegos_del_año_o_antes = df_steamgames_sin[df_steamgames_sin['release_date'].dt.year <= año]

    # Obtiengo los nombres de los juegos que se lanzaron en o antes del año especificado:
    juegos_lanzados_hasta_ano = juegos_del_año_o_antes['nombre_del_juego']

    # Filtro df_items_sin para obtener las reseñas de los juegos lanzados en o antes del año especificado
    reseñas_del_año_o_antes = df_items_sin[df_items_sin['item_id'].isin(juegos_lanzados_hasta_ano)]

    # Agrupo las reseñas por el nombre del juego y calcula el promedio de las recomendaciones
    promedio_recomendaciones_por_juego = reseñas_del_año_o_antes.groupby('item_id')['recommend'].mean()

    # Ordeno los juegos por promedio de recomendaciones en orden descendente y toma los 3 mejores
    top_3_juegos_recomendados = promedio_recomendaciones_por_juego.nlargest(3)

    return {"Top 3 de juegos más recomendados lanzados hasta el año {}: {}".format(año, top_3_juegos_recomendados.to_dict())}
